# %%
import os
import scipy.misc
from skimage.util.shape import view_as_windows
from sklearn.feature_extraction import image
import numpy as np

from forward_model import DCGAN
from utils import pp, visualize, to_json, show_all_variables

import tensorflow as tf

from glob import glob
from ops import *
from utils import *

import matplotlib.pyplot as plt
import ra

# %matplotlib notebook

# %%
#flags

flags = tf.app.flags
flags.DEFINE_integer("epoch", 15, "Epoch to train [20]") # changed from  15
flags.DEFINE_float("learning_rate", 0.0002, "Learning rate of for adam [0.0002]")
flags.DEFINE_float("beta1", 0.5, "Momentum term of adam [0.5]")
flags.DEFINE_integer("train_size", np.inf, "The size of train images [np.inf]")
flags.DEFINE_integer("batch_size", 64, "The size of batch images [64]")
flags.DEFINE_integer("input_height", 64, "The size of image to use (will be center cropped). [108]")
flags.DEFINE_integer("input_width", 80, "The size of image to use (will be center cropped). If None, same value as input_height [None]")
flags.DEFINE_integer("output_height", 64, "The size of the output images to produce [64]")
flags.DEFINE_integer("output_width", 80, "The size of the output images to produce. If None, same value as output_height [None]")
flags.DEFINE_string("dataset", "train_img_slices", "The name of dataset [celebA, mnist, lsun]")
flags.DEFINE_string("input_fname_pattern", "*.jpg", "Glob pattern of filename of input images [*]")
flags.DEFINE_string("checkpoint_dir", "patch_checkpoint", "Directory name to save the checkpoints [checkpoint]")
flags.DEFINE_string("sample_dir", "patch_samples", "Directory name to save the image samples [samples]")
flags.DEFINE_boolean("train", False, "True for training, False for testing [False]")
flags.DEFINE_boolean("crop", False, "True for training, False for testing [False]")
flags.DEFINE_boolean("visualize", False, "True for visualizing, False for nothing [False]")
FLAGS = flags.FLAGS

pp.pprint(flags.FLAGS.__flags)

if FLAGS.input_width is None:
    FLAGS.input_width = FLAGS.input_height
if FLAGS.output_width is None:
    FLAGS.output_width = FLAGS.output_height

if not os.path.exists(FLAGS.checkpoint_dir):
    os.makedirs(FLAGS.checkpoint_dir)
if not os.path.exists(FLAGS.sample_dir):
    os.makedirs(FLAGS.sample_dir)

#gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.333)
run_config = tf.ConfigProto()
run_config.gpu_options.allow_growth=True
# Out:
# {}

# %%
data = sorted(glob("./Patches/*.npy"))
sample_files = data[0:64]
sample = [imread_new(d) for d in sample_files]

# %%
plt.imshow(patch_together(sample[0:16]), cmap ='gray')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
v = np.reshape(sample, (64, 64*80))

# %%
num_iter = 500
all_patches = []
with tf.Session() as sess:

    dcgan = DCGAN(
        sess,
        input_width=FLAGS.input_width,
        input_height=FLAGS.input_height,
        output_width=FLAGS.output_width,
        output_height=FLAGS.output_height,
        batch_size=FLAGS.batch_size,
        sample_num=FLAGS.batch_size,
        dataset_name=FLAGS.dataset,
        input_fname_pattern=FLAGS.input_fname_pattern,
        crop=FLAGS.crop,
        checkpoint_dir=FLAGS.checkpoint_dir,
        sample_dir=FLAGS.sample_dir)



    if not dcgan.load(FLAGS.checkpoint_dir)[0]:
        raise Exception("[!] Train a model first, then run test mode")

    dcgan.z.initializer.run()

    for i in range(1):
        count = 0
        y_placeholder = tf.placeholder(tf.float32,[64,64*80])
        

        
        # -----------------------------------
        our_loss = tf.reduce_mean(tf.reduce_sum((tf.reshape(dcgan.G, [64, -1]) - y_placeholder)**2, 1))
        # -----------------------------------

        z_optim = tf.train.AdamOptimizer(learning_rate=0.1).minimize(our_loss, var_list=dcgan.z)  

        opt_initializers   = [var.initializer for var in tf.global_variables() if 'Adam' in var.name]
        beta1_initializers = [var.initializer for var in tf.global_variables() if 'beta1_power' in var.name]
        beta2_initializers = [var.initializer for var in tf.global_variables() if 'beta2_power' in var.name]

        sess.run(opt_initializers)
        sess.run(beta1_initializers)
        sess.run(beta2_initializers)


        for i in range(num_iter): 
            print('iteration {}'.format(count))
            a, closs, b = sess.run([z_optim, our_loss, dcgan.G],feed_dict={y_placeholder: v})
            count += 1
            print(closs)
        all_patches.append(b)
# Out:
#  [*] Reading checkpoints...
# WARNING:tensorflow:From /home/shloakuser/mri/forward_model.py:513: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# z:0
# generator/g_h0_lin/Matrix:0
# generator/g_h0_lin/bias:0
# generator/g_bn0/beta:0
# generator/g_bn0/gamma:0
# generator/g_bn0/moving_mean:0
# generator/g_bn0/moving_variance:0
# generator/g_h1/w:0
# generator/g_h1/biases:0
# generator/g_bn1/beta:0
# generator/g_bn1/gamma:0
# generator/g_bn1/moving_mean:0
# generator/g_bn1/moving_variance:0
# generator/g_h2/w:0
# generator/g_h2/biases:0
# generator/g_bn2/beta:0
# generator/g_bn2/gamma:0
# generator/g_bn2/moving_mean:0
# generator/g_bn2/moving_variance:0
# generator/g_h3/w:0
# generator/g_h3/biases:0
# generator/g_bn3/beta:0
# generator/g_bn3/gamma:0
# generator/g_bn3/moving_mean:0
# generator/g_bn3/moving_variance:0
# generator/g_h4/w:0
# generator/g_h4/biases:0
# discriminator/d_h0_conv/w:0
# discriminator/d_h0_conv/biases:0
# discriminator/d_h1_conv/w:0
# discriminator/d_h1_conv/biases:0
# discriminator/d_bn1/beta:0
# discriminator/d_bn1/gamma:0
# discriminator/d_bn1/moving_mean:0
# discriminator/d_bn1/moving_variance:0
# discriminator/d_h2_conv/w:0
# discriminator/d_h2_conv/biases:0
# discriminator/d_bn2/beta:0
# discriminator/d_bn2/gamma:0
# discriminator/d_bn2/moving_mean:0
# discriminator/d_bn2/moving_variance:0
# discriminator/d_h3_conv/w:0
# discriminator/d_h3_conv/biases:0
# discriminator/d_bn3/beta:0
# discriminator/d_bn3/gamma:0
# discriminator/d_bn3/moving_mean:0
# discriminator/d_bn3/moving_variance:0
# discriminator/d_h4_lin/Matrix:0
# discriminator/d_h4_lin/bias:0
# WARNING:tensorflow:From /home/shloakuser/mri/forward_model.py:517: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# INFO:tensorflow:Restoring parameters from patch_checkpoint/train_img_slices_64_64_80/DCGAN.model-10502
#  [*] Success to read DCGAN.model-10502
# iteration 0
# 433.141
# iteration 1
# 322.66
# iteration 2
# 270.88
# iteration 3
# 241.271
# iteration 4
# 229.877
# iteration 5
# 215.913
# iteration 6
# 206.684
# iteration 7
# 199.498
# iteration 8
# 193.206
# iteration 9
# 187.355
# iteration 10
# 182.952
# iteration 11
# 179.453
# iteration 12
# 175.547
# iteration 13
# 171.673
# iteration 14
# 169.006
# iteration 15
# 166.389
# iteration 16
# 163.47
# iteration 17
# 161.031
# iteration 18
# 158.659
# iteration 19
# 155.88
# iteration 20
# 152.942
# iteration 21
# 150.61
# iteration 22
# 148.243
# iteration 23
# 145.752
# iteration 24
# 143.915
# iteration 25
# 142.625
# iteration 26
# 141.435
# iteration 27
# 139.843
# iteration 28
# 138.284
# iteration 29
# 137.019
# iteration 30
# iteration 389
# 42.5622
# iteration 390
# 42.9372
# iteration 391
# 42.6508
# iteration 392
# 42.6541
# iteration 393
# 42.5691
# iteration 394
# 42.537
# iteration 395
# 42.4222
# iteration 396
# 42.5565
# iteration 397
# 42.2927
# iteration 398
# 42.4209
# iteration 399
# 42.5446
# iteration 400
# 42.4593
# iteration 401
# 42.3315
# iteration 402
# 42.6032
# iteration 403
# 42.3112
# iteration 404
# 42.3878
# iteration 405
# 42.1337
# iteration 406
# 42.3858
# iteration 407
# 42.3601
# iteration 408
# 42.1371
# iteration 409
# 42.0226
# iteration 410
# 42.153
# iteration 411
# 42.0838
# iteration 412
# 41.8669
# iteration 413
# 41.9196
# iteration 414
# 42.0245
# iteration 415
# 42.2218
# iteration 416
# 42.1228
# iteration 417
# 41.9324
# iteration 418
# 41.9669
# iteration 419
# 41.9302
# iteration 420
# 42.0993
# iteration 421
# 41.6755
# iteration 422
# 42.023
# iteration 423
# 41.6864
# iteration 424
# 41.7634
# iteration 425
# 41.6631
# iteration 426
# 41.5745
# iteration 427
# 41.589
# iteration 428
# 41.857
# iteration 429
# 41.6781
# iteration 430
# 41.6238
# iteration 431
# 41.5385
# iteration 432
# 41.7482
# iteration 433
# 41.4708
# iteration 434
# 42.0766
# iteration 435
# 41.2161
# iteration 436
# 41.4793
# iteration 437
# 41.3619
# iteration 438
# 41.3388
# iteration 439
# 41.312
# iteration 440
# 41.1094
# iteration 441
# 41.1569
# iteration 442
# 41.1682
# iteration 443
# 41.2158
# iteration 444
# 40.9678
# iteration 445
# 40.8214
# iteration 446
# 41.2043
# iteration 447
# 40.9427
# iteration 448
# 41.078
# iteration 449
# 40.8689
# iteration 450
# 40.9677
# iteration 451
# 41.0645
# iteration 452
# 40.9999
# iteration 453
# 41.0342
# iteration 454
# 40.8156
# iteration 455
# 41.1544
# iteration 456
# 41.0329
# iteration 457
# 40.9851
# iteration 458
# 40.7427
# iteration 459
# 40.7482
# iteration 460
# 40.8247
# iteration 461
# 40.8628
# iteration 462
# 40.8587
# iteration 463
# 40.5338
# iteration 464
# 40.5908
# iteration 465
# 40.6333
# iteration 466
# 40.6616
# iteration 467
# 40.6765
# iteration 468
# 40.7963
# iteration 469
# 40.5067
# iteration 470
# 40.7722
# iteration 471
# 40.6279
# iteration 472
# 40.8152
# iteration 473
# 40.693
# iteration 474
# 40.6542
# iteration 475
# 40.5607
# iteration 476
# 40.5416
# iteration 477
# 40.5098
# iteration 478
# 40.4225
# iteration 479
# 40.7491
# iteration 480
# 40.5183
# iteration 481
# 40.586
# iteration 482
# 40.2867
# iteration 483
# 40.3432
# iteration 484
# 40.4144
# iteration 485
# 40.4156
# iteration 486
# 40.8215
# iteration 487
# 40.261
# iteration 488
# 40.2046
# iteration 489
# 40.2743
# iteration 490
# 40.0955
# iteration 491
# 40.3241
# iteration 492
# 40.5051
# iteration 493
# 40.2504
# iteration 494
# 40.3715
# iteration 495
# 40.2542
# iteration 496
# 40.247
# iteration 497
# 40.0995
# iteration 498
# 40.2772
# iteration 499
# 39.945

# %%
num = 3
np.shape(all_patches[0])
pics = np.reshape(all_patches, (64, 64, 80))
plt.imshow(patch_together(pics[num*16:(num+1)*16]), cmap ='gray')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
