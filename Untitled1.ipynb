# %%
import ra

from glob import glob
from ops import *
from utils import *
import os

# %%
data = glob("./masks/masks/*.ra")

# %%
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np

img = ra.read_ra(data[3])
mag = abs(img)
plt.figure()
plt.imshow(mag, cmap='gray')
plt.show()

# %%
y = mag.reshape(-1)
y = np.sort(y)

# %%
y.shape
# Out:
# (81920,)

# %%
mag.shape
# Out:
# (256, 320)

# %%
mag = (mag > 0.5)*1.

# %%
plt.imshow(mag)
plt.show()

# %%
the_mask = np.fft.fftshift(mag)

# %%
plt.imshow(the_mask)
plt.show()

# %%
the_mask2 = np.fft.ifftshift(mag)
plt.imshow(the_mask2)
plt.show()

print((the_mask != the_mask2).any())
# Out:
# False

# %%
plt.plot(y)
plt.show()
