# %%
import sys 
sys.path.append('..')
import matplotlib.pyplot as plt
from glob import glob
import ra
import numpy as np
import pylab 
import scipy.stats as stats
from utils import *

def show_images(images, cols = 1):
    n_images = len(images)
    fig = plt.figure()
    for n, image in enumerate(images):
        a = fig.add_subplot(cols, np.ceil(n_images/float(cols)), n + 1)
        plt.imshow(image, cmap='gray')
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)
    plt.show()

# %%
a1 = np.load('./data/recon_mri_new/mri_orig.npy')
plt.imshow(a1, cmap='gray')
plt.show()
a = np.load('./data/recon_mri_new/mri_fft.npy')
b = np.load('./data/recon_fft_compare/mri_fft.npy')
show_images([b, a])

#original
#no subsample recon on subsample (4x) train vs no subsample recon on no subsample train

# %%
a1 = np.load('./data/recon_mri_new/mri_orig.npy')
plt.imshow(a1, cmap='gray')
plt.show()
a = np.load('./data/recon_mri_new/mri_fft_2.npy')
b = np.load('./data/recon_mri_new/mri_fft_4.npy')
c = np.load('./data/recon_mri_new/mri_fft_8.npy')
show_images([a, b, c])
a = np.load('./data/recon_fft_compare/mri_fft_2x.npy')
b = np.load('./data/recon_fft_compare/mri_fft_4x.npy')
c = np.load('./data/recon_fft_compare/mri_fft_8x.npy')
show_images([a, b, c])
#2x, 4x, 8x subsample recon on subsample train (4x)
#2x, 4x, 8x subsample recon on no subsample train

# %%
a = np.load('./data/recon_mri_new/mri_fft_2.npy')
b = np.load('./data/recon_mri_new/mri_fft_4.npy')
c = np.load('./data/recon_mri_new/mri_fft_8.npy')
show_images([a, b, c])
a = np.load('./data/recon_mri_new_6/mri_fft_2.npy')
b = np.load('./data/recon_mri_new_6/mri_fft_4.npy')
c = np.load('./data/recon_mri_new_6/mri_fft_8.npy')
show_images([a, b, c])
