# %%
from skimage import color
from skimage import io
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


data = glob("../img_align_celeba/*.jpg")[:3000]
#img = mpimg.imread(data[0])
img = color.rgb2gray(io.imread(data[888]))
np.shape(img)

plt.imshow(img, cmap='gray')
plt.show()
print(np.amax(img))
print(np.amin(img))
# Out:
# 0.865234509804
# 0.000565490196078

# %%
a = np.load('./checkpoints_face2/4_218_178/752.npy')
plt.hist(a[0])
plt.show()

# %%
b = np.load('../checkpoint_face2/train_img_slices_4_218_178/9502.npy')
print(np.shape(b))
plt.hist(b[1])
plt.show()
# Out:
# (4, 1000)

# %%
b = np.load('./checkpoints_comb/0000000149.npy')
c = np.clip(b[1], 0, 1)
print(np.median(b[0]))
print(np.median(b[1]))
print(np.median(b[2]))
plt.plot(c)
plt.show()
# Out:
# 0.0323096
# 0.452589
# 0.0257216

# %%
b = np.load('./checkpoints_comba/0000000849.npy')
print(np.median(b))
plt.plot(b)
plt.show()
# Out:
# 0.0496916

# %%
b = np.load('./checkpoints_combg/0000000049.npy')
print(np.median(b[1]))
plt.plot(b[1])
plt.show()
# Out:
# 3.3607e-05
